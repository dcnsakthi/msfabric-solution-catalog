# %% [markdown]
# > Do not commit changes to this file. Instead, make a copy of this Notebook for development and testing purposes into the `dev/` folder. Other files in the `dev/` folder are not committed to GitHub.

# %%
import importlib
import msfabric_solution_catalog as catalog

# Reload all modules including new ones
importlib.reload(catalog.logger)
importlib.reload(catalog.registry)
importlib.reload(catalog.workspace_manager)
importlib.reload(catalog.installer)
importlib.reload(catalog.ui)
importlib.reload(catalog.core)
catalog.list(show_unlisted=True)
# Out:
# [notice] A new release of fabric-cicd is available: 0.1.34 -> 0.3.1
# [notice] View the full changelog at: https://microsoft.github.io/fabric-cicd/latest/changelog/
# <style>/* ============================================================================
#    Fabric catalog UI Styles
#    Unified CSS for list view and install status displays
#    ============================================================================ */
#
# /* Global styles */
# * {
#     box-sizing: border-box;
# }
#
# /* ============================================================================
#    catalog List View
#    ============================================================================ */
#
# .catalog-container {
#     font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, 'Roboto', 'Helvetica Neue', sans-serif;
#     max-height: 980px;
#     overflow: auto;
#     overscroll-behavior: contain;
#     margin: 0 auto;
#     padding: 40px 20px;
#     background: #fafafa;
# }
#
# ...

# %%
catalog.install("analytics-roadshow-lab", workspace_id="<workspace_id>")
